# %% [markdown]
# # Zak Phase calculation for graphene nanoribbons

# %% [markdown]
# Let's make graphene and try to compute the Zak phase for different cell size and shape

# %%
# %run matplotlib_setup.ipy

from types import SimpleNamespace

from ipywidgets import interact
import matplotlib
from matplotlib import pyplot
from mpl_toolkits import mplot3d
import numpy as np
import scipy.linalg as la 

import kwant
from kwant.wraparound import wraparound, plot_2d_bands


def momentum_to_lattice(k):
    """Transform momentum to the basis of reciprocal lattice vectors.
    
    See https://en.wikipedia.org/wiki/Reciprocal_lattice#Generalization_of_a_dual_lattice
    """
    B = np.array(graphene.prim_vecs).T
    A = B.dot(np.linalg.inv(B.T.dot(B)))
    return np.linalg.solve(A, k)


def dispersion_2D(syst, args=None, lim=1.5*np.pi, num_points=200):
    """A simple plot of 2D band structure."""
    if args is None:
        args = []
    momenta = np.linspace(-lim, lim, num_points)
    energies = []
    for kx in momenta:
        for ky in momenta:
            lattice_k = momentum_to_lattice([kx, ky])
            h = syst.hamiltonian_submatrix(args=(list(args) + list(lattice_k)))
            energies.append(np.linalg.eigvalsh(h))
    
    energies = np.array(energies).reshape(num_points, num_points, -1)
    emin, emax = np.min(energies), np.max(energies)
    kx, ky = np.meshgrid(momenta, momenta)
    fig = pyplot.figure()
    axes = fig.add_subplot(1, 1, 1, projection='3d')
    for band in range(energies.shape[-1]):
        axes.plot_surface(kx, ky, energies[:, :, band], cstride=2, rstride=2,
                          cmap=matplotlib.cm.RdBu_r, vmin=emin, vmax=emax,
                          linewidth=0.1)
        
#Some helper functions to make the schematic look neat
def family_color(site): 
    if site.family == a: 
        return 0 
    else: 
        return 1
    
def hopping_lw(site1,site2): 
    return 0.1 if A in [site1.family,site2.family] else 0.05

graphene = kwant.lattice.general([[np.sqrt(3)/2,1/2],[np.sqrt(3)/2,-1/2]],  #Lattice vectors 
                                  [[0,0],[1/np.sqrt(3),0]]) # Co-ordinates
a,b = graphene.sublattices

bulk_graphene = kwant.Builder(kwant.TranslationalSymmetry(*graphene.prim_vecs))
bulk_graphene[graphene.shape((lambda pos: True), (0, 0))] = 0
bulk_graphene[graphene.neighbors(1)] = 1
kwant.plot(bulk_graphene,site_color=family_color,site_lw=0.01)
dispersion_2D(wraparound(bulk_graphene).finalized())
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:35: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.

# %%
Zigzag = kwant.lattice.general([[1,0],[0,np.sqrt(3)/3]], #Lattice vectors
                                     [[1/6,0],[2/6,np.sqrt(3)/2],[4/6,np.sqrt(3)/2],[5/6,0]]) # Coordinates

def get_width(N=7): 
    if N < 2: 
        raise("N cannot be less than 2")
    else:
        return N/2*Zigzag.prim_vecs[1][1]+0.01

def make_1D_zigzag(N=7):
    syst = kwant.Builder(kwant.TranslationalSymmetry(Zigzag.prim_vecs[0]))
    syst[Zigzag.shape((lambda pos: pos[1] >0 and pos[1] <= get_width(N)),(0,0))] = 0
    syst[Zigzag.neighbors()] = -1
    return syst

# %%
N_list =[3,11,5,7,9,8,10,4,6]
#N_list =[5]
pol_N={}
wcc_N={}
import z2pack
from Z2_compute import zak_bands as zak_bands_z2
for N in N_list:
    # Making a Zigzag lead
    Zigzag_1d = make_1D_zigzag(N=N) 
    Zigzag_1d[Zigzag.neighbors(2)] = 0.001
    kwant.plot(Zigzag_1d,site_color=family_color);
    Zigzag_1d = Zigzag_1d.finalized()
    kwant.plotter.bands(Zigzag_1d);

    act_pos = np.array([Zigzag_1d.pos(i) for i in range(2*N)])
    a1,a2 = [Zigzag.prim_vecs[0][0],get_width(N=N)]
    red_pos = np.zeros(np.shape(act_pos))
    red_pos[:,0] = act_pos[:,0]/a1
    red_pos[:,1] = act_pos[:,1]/a2


    ham_k=zak_bands_z2(Zigzag_1d,momenta=1001,dim=2)
    z2_system = z2pack.hm.System(ham_k,dim=2,#pos=red_pos,
                                 convention=2)
    pol_sum = 0
    for n in range(0,1):
        result1 = z2pack.line.run(system=z2_system, 
                                 line=lambda t1: [t1,0],#,n/(N+1)])#,
                                 pos_tol=1e-3,iterator=range(200,500,2));
    #np.exp(-1*2*np.pi*np.sum(np.log(np.diagonal(result.wilson))))
    #result.pol
        #result12 = z2pack.line.run(system=z2_system, 
        #                         line=lambda t1: [t1,-n/(N+1)],
        #                         pos_tol=1e-2)
        pol_sum += result1.pol
        #pol_sum += result2.pol
        
    
    #pol_N[N] = np.sign(np.exp(-1j*2*np.pi*(pol_sum % 1)))
    pol_N[N] = pol_sum % 1
    wcc_N[N] = result1.wcc
# Out:
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:37,802                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11db9c510>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11d934e80>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:38,262                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x10becb158>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11caf76a0>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:38,890                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11d3b17b8>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11cb404e0>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:39,258                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11d3b1ea0>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x10a5f5a90>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:39,690                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11d3b17b8>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11cf27f98>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:40,199                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11d3b1ea0>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11dbfd908>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:40,695                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11db9cc80>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11d345828>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:41,148                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11db9c950>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11ccf7e48>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:16:41,509                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x11cd0f268>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11d3532b0>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+

# %%
pol_N
# Out:
# {3: 0.9999999999999992,
#  11: 0.4999999958521313,
#  5: 0.9999999968821904,
#  7: 0.4999999999999991,
#  9: 0.4999999999999991,
#  8: 0.5000000001959766,
#  10: 0.9999999999999991,
#  4: 0.5000000000000004,
#  6: 0.5}

# %% [markdown]
# # Zigzag'

# %%
Zigzag_dash = kwant.lattice.general([[1,0],[0,np.sqrt(3)/3]], #Lattice vectors
                                     [[1/6,0],[2/6,-np.sqrt(3)/2],[4/6,-np.sqrt(3)/2],[5/6,0]]) # Coordinates

def get_width_dash(N=7): 
    #if N < 2: 
        #raise("N cannot be less than 2")
    #else:
    return N/2*Zigzag_dash.prim_vecs[1][1]

def make_1D_zigzag_dash(N=7):
    syst = kwant.Builder(kwant.TranslationalSymmetry(Zigzag_dash.prim_vecs[0]))
    syst[Zigzag_dash.shape((lambda pos: pos[1] >-1*get_width_dash(1) and pos[1] <= get_width_dash(N-1)),(0,0))] = 0
    syst[Zigzag_dash.neighbors()] = -1
    return syst

# %%
N_list =[3,11,29,7,9,8,10,2,4,6]
pol_N={}
import z2pack
from Z2_compute import zak_bands as zak_bands_z2
for N in N_list:
    # Making a Zigzag lead
    Zigzag_1d_dash = make_1D_zigzag_dash(N=N) 
    Zigzag_1d_dash[Zigzag.neighbors(2)] = 0.001
    kwant.plot(Zigzag_1d_dash,site_color=family_color);
    Zigzag_1d_dash = Zigzag_1d_dash.finalized()
    kwant.plotter.bands(Zigzag_1d_dash);

    #act_pos = np.array([Zigzag_1d_dash.pos(i) for i in range(2*N)])
    #a1,a2 = [Zigzag_dash.prim_vecs[0][0],get_width(N=N)]
    #red_pos = np.zeros(np.shape(act_pos))
    #red_pos[:,0] = act_pos[:,0]/a1
    #red_pos[:,1] = act_pos[:,1]/a2


    ham_k=zak_bands_z2(Zigzag_1d_dash,momenta=1001,dim=1)
    z2_system = z2pack.hm.System(ham_k,dim=1,#pos=red_pos,
                                 convention=2)
    pol_sum = 0
    for n in range(0,1):
        result1 = z2pack.line.run(system=z2_system, 
                                 line=lambda t1: [t1],#,n/(N+1)])#,
                                 pos_tol=1e-3)#,iterator=range(200,500,2));
    #np.exp(-1*2*np.pi*np.sum(np.log(np.diagonal(result.wilson))))
    #result.pol
        #result12 = z2pack.line.run(system=z2_system, 
        #                         line=lambda t1: [t1,-n/(N+1)],
        #                         pos_tol=1e-2)
        pol_sum += result1.pol
        #pol_sum += result2.pol
        
    
    pol_N[N] = pol_sum % 1
    z2 = np.sign(np.exp(1j*2*np.pi*pol_N[N]))
# Out:
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:43,487                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x11dbd77b8>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11ea46160>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:43,862                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x11dbd76a8>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11caa09e8>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 16
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 18
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 20
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 22
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:44,551                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x10becb158>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11cf0bac8>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 16
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 18
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 20
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 22
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 1s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:45,466                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x11d05dc80>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11d160978>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:45,781                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x10becb158>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11ce58da0>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 16
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 18
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 20
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:46,147                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x11d05dc80>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11ce943c8>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 16
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 18
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 20
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 22
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:46,557                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x10becb158>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11cae5e48>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 16
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:46,850                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x11d277d90>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11d291d30>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 16
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 18
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 20
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 22
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 24
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 26
# INFO: 0 of 1 line convergence criteria fulfilled.
# WARNING: Iterator stopped before the calculation could converge.
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:47,158                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x10becb158>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11ce698d0>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-07 12:21:47,454                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x11ca4fd90>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11d4e3b70>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 14
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 16
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 18
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+

# %%
pol_N
# Out:
# {3: 0.5000000000000009,
#  11: 4.19158396880448e-09,
#  29: 0.500000001647324,
#  7: 1.7763568394002505e-15,
#  9: 0.0,
#  8: 0.49999999971540277,
#  10: 0.9999999999999991,
#  2: 0.23935155089746418,
#  4: 0.49999999999999956,
#  6: 0.5}

# %% [markdown]
# ## Bearded

# %%
Bearded = kwant.lattice.general([[1,0],[0,np.sqrt(3)/3]], #Lattice vectors
                                     [[0.5/6,np.sqrt(3)/2],[2.5/6,np.sqrt(3)/2],[3.5/6,0],[5.5/6,0]]) # Coordinates

def get_width(N=7): 
    if N < 2: 
        raise("N cannot be less than 2")
    else:
        return N/2*Zigzag.prim_vecs[1][1]+0.01

def make_1D_bearded(N=7):
    syst = kwant.Builder(kwant.TranslationalSymmetry(Bearded.prim_vecs[0]))
    syst[Bearded.shape((lambda pos: pos[1] >0 and pos[1] <= get_width(N)),(0,0))] = 0
    syst[Bearded.neighbors()] = -1
    return syst

# %%
N_list =[3,11,5,7,9,8,10,4,6,12,14]
pol_N={}
import z2pack
from Z2_compute import zak_bands as zak_bands_z2
for N in N_list:
    # Making a Zigzag lead
    beard_1d = make_1D_bearded(N=N) 
    kwant.plot(beard_1d,site_color=family_color);
    beard_1d = beard_1d.finalized()
    kwant.plotter.bands(beard_1d);

    act_pos = np.array([beard_1d.pos(i) for i in range(2*N)])
    a1,a2 = [Bearded.prim_vecs[0][0],get_width(N=N)]
    red_pos = np.zeros(np.shape(act_pos))
    red_pos[:,0] = act_pos[:,0]/a1
    red_pos[:,1] = act_pos[:,1]/a2


    ham_k=zak_bands_z2(beard_1d,momenta=1001,dim=1)
    z2_system = z2pack.hm.System(ham_k,dim=1,#pos=red_pos,
                                 convention=2)
    pol_sum = 0
    for n in range(0,1):
        result1 = z2pack.line.run(system=z2_system, 
                                 line=lambda t1: [t1])#,n/(N+1)])#,
                                 #pos_tol=1e-3,iterator=range(200,500,2));
    #np.exp(-1*2*np.pi*np.sum(np.log(np.diagonal(result.wilson))))
    #result.pol
        #result12 = z2pack.line.run(system=z2_system, 
        #                         line=lambda t1: [t1,-n/(N+1)],
        #                         pos_tol=1e-2)
        pol_sum += result1.pol
        #pol_sum += result2.pol
        
    
    #pol_N[N] = np.sign(np.exp(-1j*2*np.pi*(pol_sum % 1)))
    pol_N[N] = pol_sum % 1
# Out:
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:19,092                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x105656f28>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x1056373c8>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:19,438                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x1165810d0>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x116e71240>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:19,823                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x1165811e0>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x116432400>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:20,157                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x1165810d0>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x1166a3f28>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:20,475                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x117590620>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x1184b3438>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:20,805                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x1165810d0>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x116b872e8>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:21,183                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x1186fed08>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x11759d9b0>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:21,487                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x118291e18>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x116998748>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:21,797                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x116e6b6a8>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x1175fa438>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:22,132                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x117590488>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x1186efa90>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-05 15:47:22,491                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(8, 27, 2)                                  |
# |        line:        <function <lambda> at 0x116e6bc80>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.01                                             |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x117596780>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 8
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 10
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 12
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+

# %%
pol_N
# Out:
# {3: 0.49999999999999933,
#  11: 0.7231339782110195,
#  5: 0.7237860901875299,
#  7: 8.881784197001252e-16,
#  9: 0.5000000000000004,
#  8: 0.22378609018753082,
#  10: 0.4999999999999991,
#  4: 0.5000000000000009,
#  6: 0.9999999999999973,
#  12: 0.9999999999999956,
#  14: 0.18380428880200483}
