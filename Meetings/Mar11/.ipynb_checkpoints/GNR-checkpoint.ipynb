# %% [markdown]
# #### Settings used for the Notebook and helper functions

# %%
# %run notebook_setup.ipy
from helper import *
from Z2_compute import calc_pol

N_odd =[3,5,7,9,11]
N_even = [4,6,8,10,12]

# %% [markdown]
# # Z2 calculator for 1D system on a graphene lattice using Z2pack and Kwant
#
# Below is the polarization calculation for N = odd systems with zigzag termination in Steven Louie PRL paper

# %%
pol_N={}
for N in N_odd:
    Armchair_1d = make_1D_cell(N=N)
    kwant.plot(Armchair_1d,site_color=family_color);
    Armchair_1d = Armchair_1d.finalized()
    kwant.plotter.bands(Armchair_1d,momenta=101);
    act_pos = np.array([Armchair_1d.pos(i) for i in range(2*N)])
    a1,a2 = [Armchair.prim_vecs[0][0],get_width(N,Armchair)]
    red_pos = np.zeros(np.shape(act_pos))
    red_pos[:,0] = act_pos[:,0]/a1
    red_pos[:,1] = act_pos[:,1]/a2
    pol_N[N] = calc_pol(Armchair_1d,red_pos)
print("=============================================")
print("Polarization as a function of N:",pol_N)
# Out:
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:42:56,575                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c139b70>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c86b8d0>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:42:57,005                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c139b70>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11bfbc5f8>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 11
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:42:57,544                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x10b1561e0>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c0b4c18>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:42:57,969                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c0fff28>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c1cf8d0>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:42:58,542                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11bf19620>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x109db7400>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 11
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# =============================================
# Polarization as a function of N: {3: 0.5000000000000004, 5: 0.2792489746581377, 7: 1.7763568394002505e-15, 9: 0.0, 11: 0.22075102534186097}

# %% [markdown]
# # Steven Louie PRL, 2017
#
# ![title](./images/Steven_Louie_table.png)
#
# ### N = 5 and 7 does not match because they are gapless.
#
# ### The WCC at the ${\Gamma}$ point is not well-defined and the eigenvectors can get mixed.
#
# ### Although simple tight binding implies gapless dispersion, DFT shows that there is a non-zero gap
#
# # DFT bandstrcuture for N=5
# ![title](./images/band_5.png)
#
# ## Steven Louie, PRL 2006
#
# ![title](./images/Steven_Louie_energy_gaps_plot.png)

# %% [markdown]
# ## Considering the effect of edge termination opens a band gap
#
# The overlap between the edge bonds parallel to the edge is increased to account for the bond shrinkage due to the termination

# %%
pol_N={}
for N in N_odd:
    Armchair_1d = make_1D_cell(N=N)
    #####################################################
    # Adding edge termination by increasing the overlap #
    # of the edge bonds
    #####################################################
    lat = lat_dict['armchair']
    Armchair_1d = terminate_edges(Armchair_1d,-0.1,3)

    kwant.plot(Armchair_1d,site_color=family_color);
    Armchair_1d = Armchair_1d.finalized()
    kwant.plotter.bands(Armchair_1d,momenta=101);
    act_pos = np.array([Armchair_1d.pos(i) for i in range(2*N)])
    a1,a2 = [Armchair.prim_vecs[0][0],get_width(N,Armchair)]
    red_pos = np.zeros(np.shape(act_pos))
    red_pos[:,0] = act_pos[:,0]/a1
    red_pos[:,1] = act_pos[:,1]/a2
    pol_N[N] = calc_pol(Armchair_1d,red_pos)
print("=============================================")
print("Polarization as a function of N:",pol_N)
# Out:
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:43:05,263                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c1d09d8>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11be7fd30>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:43:05,702                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c6e8bf8>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c268518>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:43:06,140                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x119d5abf8>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c0b06d8>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:43:06,565                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c05f730>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c236be0>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:43:07,198                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c05f9d8>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x116a42320>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# =============================================
# Polarization as a function of N: {3: 0.5000000000000009, 5: 0.9999999999999902, 7: 1.7763568394002505e-15, 9: 0.9999999999999996, 11: 0.4999999999999787}

# %% [markdown]
# ## Translating the unit cell box over the fixed lattice changes the Z2 invariant

# %%
pol_N={}
for N in N_odd:
    offset = -1*get_width(1,lat_dict['armchair'])
    Armchair_1d = make_1D_cell(N=N,offset=offset)
    #####################################################
    # Adding edge termination by increasing the overlap #
    # of the edge bonds
    #####################################################
    lat = lat_dict['armchair_trans']
    Armchair_1d = terminate_edges(Armchair_1d,-0.1,3)
    kwant.plot(Armchair_1d,site_color=family_color);
    Armchair_1d = Armchair_1d.finalized()
    kwant.plotter.bands(Armchair_1d,momenta=101);
    act_pos = np.array([Armchair_1d.pos(i) for i in range(2*N)])
    a1,a2 = [Armchair.prim_vecs[0][0],get_width(N,Armchair)]
    red_pos = np.zeros(np.shape(act_pos))
    red_pos[:,0] = act_pos[:,0]/a1
    red_pos[:,1] = act_pos[:,1]/a2
    pol_N[N] = calc_pol(Armchair_1d,red_pos)
print("=============================================")
print("Polarization as a function of N:",pol_N)
# Out:
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:46:18,657                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c2a86a8>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11cb617f0>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:46:19,080                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c2a80d0>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11cb79a58>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:46:19,483                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c72b1e0>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x10b0a41d0>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:46:19,878                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c6e8048>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c95e6a0>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |  ================                                                    |
# |  LINE CALCULATION                                                    |
# |  ================                                                    |
# |  starting at 2019-03-18 14:46:20,304                                 |
# |  running Z2Pack version 2.1.1                                        |
# |                                                                      |
# |  init_result: None                                                   |
# |  iterator:    range(3, 501, 2)                                       |
# |  line:        <function calc_pol.<locals>.<lambda> at 0x11c863b70>   |
# |  load:        False                                                  |
# |  load_quiet:  True                                                   |
# |  pos_tol:     0.01                                                   |
# |  save_file:   None                                                   |
# |  serializer:  auto                                                   |
# |  system:      <z2pack.hm.System object at 0x11c710198>               |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 3
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 5
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 7
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                          ==================                          |
# |                          CONVERGENCE REPORT                          |
# |                          ==================                          |
# |                                                                      |
# |                          PosCheck: PASSED                            |
# +----------------------------------------------------------------------+
# =============================================
# Polarization as a function of N: {3: 4.440892098500626e-16, 5: 0.49999999999994227, 7: 0.5000000000000004, 9: 0.5, 11: 0.9999999999999485}

# %% [markdown]
# All the results from Steven Louie PRL thus agrees after correcting for the termination

# %% [markdown]
# # DFT validation
#
# ### N=7 (both zigzag and zigzag') and N=6 agrees with PRL and TB
#
# ## (Still working)
#
# ### N=5 and N=10 are incomplete. Convergence in Z2pack is problematic with DFT. Depends on the number of bands considered for Wannier
