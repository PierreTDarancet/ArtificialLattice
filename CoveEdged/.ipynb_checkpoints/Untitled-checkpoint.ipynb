# %%
# %run notebook_setup.ipy
from helper import *

# %%
N=12
L=6
Z7 = make_cove_edged_graphene(N=N,L=L)
fig = kwant.plot(Z7,site_color=family_color,site_lw=0.01);

# %%
sites = list(Z7.sites())
pos = [ site.pos for site in sites]
chevron_lattice = kwant.lattice.general([[get_length(L),0],[0,get_width(N)]],pos)
chevron_ribbon = kwant.Builder(kwant.TranslationalSymmetry(chevron_lattice.prim_vecs[0]))
chevron_ribbon[chevron_lattice.shape((lambda pos: 0 <= pos[1] < get_width(N)),(0,0))]=1
chevron_ribbon[chevron_lattice.neighbors()] = -1
fig = kwant.plot(chevron_ribbon,site_color=family_color,site_lw=0.01);
chevron_ribbon = chevron_ribbon.finalized()
kwant.plotter.bands(chevron_ribbon);

# %%
pol_N={}
wcc_N={}
import z2pack
from Z2_compute import zak_bands as zak_bands_z2

act_pos = np.array([chevron_ribbon.pos(i) for i in range(len(sites))])
a1,a2 = [chevron_lattice.prim_vecs[0][0],get_width(N=N)]
red_pos = np.zeros(np.shape(act_pos))
red_pos[:,0] = act_pos[:,0]/a1
red_pos[:,1] = act_pos[:,1]/a2


ham_k=zak_bands_z2(chevron_ribbon,momenta=1001,dim=2)
z2_system = z2pack.hm.System(ham_k,dim=2,pos=red_pos,
                                 convention=2)
result = z2pack.line.run(system=z2_system, 
                        line=lambda t1: [t1,0],#,n/(N+1)])#,
                        pos_tol=1e-3,iterator=range(200,500,2));
# Out:
# +----------------------------------------------------------------------+
# |        ================                                              |
# |        LINE CALCULATION                                              |
# |        ================                                              |
# |        starting at 2019-03-06 20:27:16,638                           |
# |        running Z2Pack version 2.1.1                                  |
# |                                                                      |
# |        init_result: None                                             |
# |        iterator:    range(200, 500, 2)                               |
# |        line:        <function <lambda> at 0x126f98400>               |
# |        load:        False                                            |
# |        load_quiet:  True                                             |
# |        pos_tol:     0.001                                            |
# |        save_file:   None                                             |
# |        serializer:  auto                                             |
# |        system:      <z2pack.hm.System object at 0x127a7b828>         |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 200
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 202
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 204
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 206
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 208
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 210
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 212
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 214
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 216
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 218
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 220
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 222
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 224
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 226
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 228
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 230
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 232
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 234
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 236
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 238
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 240
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 242
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 244
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 246
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 248
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 250
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 252
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 254
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 256
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 258
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 260
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 262
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 264
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 266
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 268
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 270
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 272
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 274
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 276
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 278
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 280
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 282
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 284
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 286
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 288
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 290
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 292
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 294
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 296
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 298
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-584f5fca42f7> in <module>
#      16 result = z2pack.line.run(system=z2_system,
#      17                         line=lambda t1: [t1,0],#,n/(N+1)])#,
# ---> 18                         pos_tol=1e-3,iterator=range(200,500,2));
#
# ~/.local/lib/python3.6/site-packages/z2pack/line/_run.py in run_line(system, line, pos_tol, iterator, save_file, init_result, load, load_quiet, serializer)
#     115             raise ValueError('Directory {} does not exist.'.format(dirname))
#     116
# --> 117     return _run_line_impl(*controls, system=system, line=line, save_file=save_file, init_result=init_result)
#     118
#     119
#
# ~/.local/lib/python3.6/site-packages/z2pack/line/_run.py in _run_line_impl(system, line, save_file, init_result, serializer, *controls)
#     200
#     201         data = DataType(system_fct(
# --> 202             list(np.array(line(k)) for k in np.linspace(0., 1., run_options['num_steps']))
#     203         ))
#     204
#
# ~/.local/lib/python3.6/site-packages/z2pack/hm.py in get_eig(self, kpt)
#      90                         format(diff, self._hermitian_tol)
#      91                     )
# ---> 92             eigval, eigvec = la.eigh(ham)
#      93             eigval = np.real(eigval)
#      94             idx = eigval.argsort()
#
# /anaconda3/lib/python3.6/site-packages/scipy/linalg/decomp.py in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite)
#     430         if eigvals is None:
#     431             w, v, info = evr(a1, uplo=uplo, jobz=_job, range="A", il=1,
# --> 432                              iu=a1.shape[0], overwrite_a=overwrite_a)
#     433         else:
#     434             (lo, hi) = eigvals
#
# KeyboardInterrupt:

# %%
result.pol
# Out:
# 0.49999999999999467

# %% [markdown]
# # Translated

# %%
def translate(pos,t,N=N,L=L):
    pos = np.array(pos)
    pos[:,0] += t 
    for p in pos: 
        if p[0] >= get_length(L): 
            p[0] -= get_length(L)
    return pos

# %%
sites = list(Z7.sites())
pos = [ site.pos for site in sites]
pos = translate(pos,get_length(L)/2)
chevron_lattice = kwant.lattice.general([[get_length(L),0],[0,get_width(N)]],pos)
chevron_ribbon = kwant.Builder(kwant.TranslationalSymmetry(chevron_lattice.prim_vecs[0]))
chevron_ribbon[chevron_lattice.shape((lambda pos: 0 <= pos[1] < get_width(N)),(0,0))]=1
chevron_ribbon[chevron_lattice.neighbors()] = -1
fig = kwant.plot(chevron_ribbon,site_color=family_color,site_lw=0.01);
chevron_ribbon = chevron_ribbon.finalized()
kwant.plotter.bands(chevron_ribbon);
